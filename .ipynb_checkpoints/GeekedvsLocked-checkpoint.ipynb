# %%
# !pip install fastai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastai in c:\users\mmist\appdata\roaming\python\python313\site-packages (2.8.4)
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (from fastai) (25.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastai) (24.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (1.8.12)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (0.23.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from fastai) (3.10.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from fastai) (2.2.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from fastai) (2.32.3)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from fastai) (6.0.2)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\programdata\anaconda3\lib\site-packages (from fastai) (11.1.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.6.1)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.15.3)
# Requirement already satisfied: spacy<4 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (3.8.7)
# Requirement already satisfied: plum-dispatch in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (2.5.8)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from fastai) (3.0.0)
# Requirement already satisfied: torch<2.9,>=1.10 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from fastai) (2.8.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.10.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (72.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from spacy<4->fastai) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch<2.9,>=1.10->fastai) (3.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from torch<2.9,>=1.10->fastai) (1.13.3)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch<2.9,>=1.10->fastai) (3.4.2)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch<2.9,>=1.10->fastai) (2025.3.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (7.3.1)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai) (1.17.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<2.9,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->fastai) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas->fastai) (2025.2)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\mmist\appdata\roaming\python\python313\site-packages (from plum-dispatch->fastai) (0.22.2)
# Requirement already satisfied: rich>=10.0 in c:\programdata\anaconda3\lib\site-packages (from plum-dispatch->fastai) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.0->plum-dispatch->fastai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.0->plum-dispatch->fastai) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->fastai) (0.1.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (3.5.0)

# %%
from fastai.vision.all import *

path = 'images'
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=6)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.604150</td>
#       <td>0.033441</td>
#       <td>0.011142</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 03:46&lt;01:53]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.033004</td>
#       <td>0.032706</td>
#       <td>0.008357</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.018665</td>
#       <td>0.007869</td>
#       <td>0.002786</td>
#       <td>01:46</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='21' class='' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       47.73% [21/44 00:43&lt;00:47 0.0126]
#     </div>

# %%
learn.export("brainrot_emotion_finder_1.pkl")
